# %% [markdown]
# <a href="https://colab.research.google.com/github/rishiprajapat/Pandas-Practice/blob/master/PandasPractice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#1
df=pd.read_excel("coalpublic2013.xls",skiprows=3)
df.head()
# Out:
#    Year  MSHA ID                       Mine Name Mine State Mine County  \
# 0  2013   103381            Tacoa Highwall Miner    Alabama        Bibb
# 1  2013   103404                Reid School Mine    Alabama      Blount
# 2  2013   100759  North River #1 Underground Min    Alabama     Fayette
# 3  2013   103246                      Bear Creek    Alabama    Franklin
# 4  2013   103451                     Knight Mine    Alabama    Franklin
#
#                           Mine Status    Mine Type  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                    Company Type              Operation Type  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# ...

# %%
#3
df[["Year","Mine Status","Production (short tons)"]]
# Out:
#       Year                         Mine Status  Production (short tons)
# 0     2013  Active, men working, not producing                    56004
# 1     2013               Permanently abandoned                    28807
# 2     2013  Active, men working, not producing                  1440115
# 3     2013                              Active                    87587
# 4     2013                              Active                   147499
# 5     2013                  Temporarily closed                    69339
# 6     2013                              Active                        0
# 7     2013                              Active                  2269014
# 8     2013                              Active                        0
# 9     2013                              Active                  1453024
# 10    2013                              Active                   327780
# 11    2013                              Active                   175058
# ...

# %%
#2
df.dtypes
# Out:
# Year                          int64
# MSHA ID                       int64
# Mine Name                    object
# Mine State                   object
# Mine County                  object
# Mine Status                  object
# Mine Type                    object
# Company Type                 object
# Operation Type               object
# Operating Company            object
# Operating Company Address    object
# Union Code                   object
# Coal Supply Region           object
# Production (short tons)       int64
# Average Employees             int64
# Labor Hours                   int64
# dtype: object

# %%
#4
print("Sum: ",df["Production (short tons)"].sum()) 
print("Mean: ",df["Production (short tons)"].mean())
print("Maximum: ",df["Production (short tons)"].max())
print("Minimum: ",df["Production (short tons)"].min())
# Out:
# Sum:  984841779
# Mean:  679201.2268965517
# Maximum:  111005549
# Minimum:  0

# %%
#5
import numpy as np
df.insert(3, "column1", np.nan)
df.head()
# Out:
#    Year  MSHA ID                       Mine Name  column1 Mine State  \
# 0  2013   103381            Tacoa Highwall Miner      NaN    Alabama
# 1  2013   103404                Reid School Mine      NaN    Alabama
# 2  2013   100759  North River #1 Underground Min      NaN    Alabama
# 3  2013   103246                      Bear Creek      NaN    Alabama
# 4  2013   103451                     Knight Mine      NaN    Alabama
#
#   Mine County                         Mine Status    Mine Type  \
# 0        Bibb  Active, men working, not producing      Surface
# 1      Blount               Permanently abandoned      Surface
# 2     Fayette  Active, men working, not producing  Underground
# 3    Franklin                              Active      Surface
# 4    Franklin                              Active      Surface
#
#                    Company Type              Operation Type  \
# 0  Indepedent Producer Operator                   Mine only
# ...

# %%
#6
df1 = pd.read_excel('coalpublic2013.xls', skiprows = 20)
df1
# Out:
#       2013   103432                   Skelton Creek          Alabama  \
# 0     2013   103437         Black Warrior Mine No 1          Alabama
# 1     2013   102976   Piney Woods Preparation Plant          Alabama
# 2     2013   102976   Piney Woods Preparation Plant          Alabama
# 3     2013   103380                          Calera          Alabama
# 4     2013   103380                          Calera          Alabama
# 5     2013   103422                 Clark No 1 Mine          Alabama
# 6     2013   103467             Helena Surface Mine          Alabama
# 7     2013   101247                       No 4 Mine          Alabama
# 8     2013   101401                       No 7 Mine          Alabama
# 9     2013   103172  Searles Mine No. 2, 3, 4, 5, 6          Alabama
# 10    2013   103179             Fleetwood Mine No 1          Alabama
# 11    2013   103303                    Shannon Mine          Alabama
# 12    2013   103323                   Deerlick Mine          Alabama
# ...

# %%
df.rename(columns = {'Mine Name':'Mine_Name'}, inplace = True)

# %%
#7
sum_row=df[["Production (short tons)", "Labor Hours"]].sum()
pd.DataFrame(sum_row).T
# Out:
#    Production (short tons)  Labor Hours
# 0                984841779    177910757

# %%
#8
df.tail(n=10)
# Out:
#       Year  MSHA ID              Mine_Name  column1       Mine State  \
# 1440  2013  3609405                Phoenix      NaN  Refuse Recovery
# 1441  2013   100515      Mary Lee # 1 Mine      NaN  Refuse Recovery
# 1442  2013  3609337     Marco Gfcc Project      NaN  Refuse Recovery
# 1443  2013  1518401                  No. 1      NaN  Refuse Recovery
# 1444  2013  1519713             # 1 Refuse      NaN  Refuse Recovery
# 1445  2013  1103254          Fidelity Mine      NaN  Refuse Recovery
# 1446  2013  1102636                    Wfi      NaN  Refuse Recovery
# 1447  2013  4407233               Gobco #8      NaN  Refuse Recovery
# 1448  2013  1518524      Turkey Pen Refuse      NaN  Refuse Recovery
# 1449  2013  1519685  Fedscreek Refuse Pile      NaN  Refuse Recovery
#
#        Mine County                         Mine Status Mine Type  \
# 1440    Washington                              Active    Refuse
# 1441        Walker  Active, men working, not producing    Refuse
# ...

# %%
#9
df3=df[["MSHA ID","Labor Hours"]].groupby('MSHA ID').sum()
df3
# Out:
#          Labor Hours
# MSHA ID
# 100329        144002
# 100347        215295
# 100515          6240
# 100759        474784
# 100851       1001809
# 101247       1551141
# 101362        116914
# 101401       2464719
# 102901       1249811
# 102976         38021
# 102996        164093
# 103155         79990
# 103172        119542
# 103179         63745
# 103180        196963
# 103182         87314
# 103195         17411
# 103246         29193
# 103285         90584
# 103303        164388
# 103321         76366
# 103323         46381
# 103332         61394
# 103342        115123
# 103358        161805
# 103364         14324
# 103370           621
# 103372         32401
# 103375          1900
# 103376        176499
# ...              ...
# 4609427        75496
# 4609428        39811
# 4609431         2480
# 4609440        13154
# 4609448        69144
# 4609454        29793
# 4609455        21023
# 4609462         9770
# 4609468        30035
# 4609470        30342
# 4609481         2456
# ...

# %%
#10
df[df["MSHA ID"]==102901].head()
# Out:
#    Year  MSHA ID         Mine_Name  column1 Mine State Mine County  \
# 8  2013   102901  Shoal Creek Mine      NaN    Alabama   Jefferson
# 9  2013   102901  Shoal Creek Mine      NaN    Alabama   Jefferson
#
#   Mine Status    Mine Type                  Company Type  \
# 8      Active      Surface  Indepedent Producer Operator
# 9      Active  Underground  Indepedent Producer Operator
#
#                Operation Type     Operating Company  \
# 8  Mine and Preparation Plant  Drummond Company Inc
# 9  Mine and Preparation Plant  Drummond Company Inc
#
#          Operating Company Address                      Union Code  \
# 8  P.O. Box 1549, Jasper, AL 35501  United Mine Workers of America
# 9  P.O. Box 1549, Jasper, AL 35501  United Mine Workers of America
#
#     Coal Supply Region  Production (short tons)  Average Employees  \
# 8  Appalachia Southern                        0                  5
# 9  Appalachia Southern                  1453024                571
#
# ...

# %%
#11
df[df["Labor Hours"] > 20000].head()
# Out:
#    Year  MSHA ID                       Mine_Name  column1 Mine State  \
# 0  2013   103381            Tacoa Highwall Miner      NaN    Alabama
# 1  2013   103404                Reid School Mine      NaN    Alabama
# 2  2013   100759  North River #1 Underground Min      NaN    Alabama
# 3  2013   103246                      Bear Creek      NaN    Alabama
# 4  2013   103451                     Knight Mine      NaN    Alabama
#
#   Mine County                         Mine Status    Mine Type  \
# 0        Bibb  Active, men working, not producing      Surface
# 1      Blount               Permanently abandoned      Surface
# 2     Fayette  Active, men working, not producing  Underground
# 3    Franklin                              Active      Surface
# 4    Franklin                              Active      Surface
#
#                    Company Type              Operation Type  \
# 0  Indepedent Producer Operator                   Mine only
# ...

# %%
#12
#df[df["Mine_Name"].map(lambda x: x.startswith('P'))].head()

# %%
#13
df[df["MSHA ID"].isin([102976,103380])].head()
# Out:
#     Year  MSHA ID                      Mine_Name  column1 Mine State  \
# 18  2013   102976  Piney Woods Preparation Plant      NaN    Alabama
# 19  2013   102976  Piney Woods Preparation Plant      NaN    Alabama
# 20  2013   103380                         Calera      NaN    Alabama
# 21  2013   103380                         Calera      NaN    Alabama
#
#    Mine County Mine Status    Mine Type                  Company Type  \
# 18      Shelby      Active      Surface  Indepedent Producer Operator
# 19      Shelby      Active  Underground  Indepedent Producer Operator
# 20      Shelby      Active      Surface  Indepedent Producer Operator
# 21      Shelby      Active  Underground  Indepedent Producer Operator
#
#        Operation Type               Operating Company  \
# 18  Preparation Plant         Jesse Creek Mining, Llc
# 19  Preparation Plant         Jesse Creek Mining, Llc
# 20  Preparation Plant  Conrad Yelvington Distributors
# ...

# %%
#14
df.query('Mine_Name == ["Shoal Creek Mine", "Piney Woods Preparation Plant"]').head()
# Out:
#     Year  MSHA ID                      Mine_Name  column1 Mine State  \
# 8   2013   102901               Shoal Creek Mine      NaN    Alabama
# 9   2013   102901               Shoal Creek Mine      NaN    Alabama
# 18  2013   102976  Piney Woods Preparation Plant      NaN    Alabama
# 19  2013   102976  Piney Woods Preparation Plant      NaN    Alabama
#
#    Mine County Mine Status    Mine Type                  Company Type  \
# 8    Jefferson      Active      Surface  Indepedent Producer Operator
# 9    Jefferson      Active  Underground  Indepedent Producer Operator
# 18      Shelby      Active      Surface  Indepedent Producer Operator
# 19      Shelby      Active  Underground  Indepedent Producer Operator
#
#                 Operation Type        Operating Company  \
# 8   Mine and Preparation Plant     Drummond Company Inc
# 9   Mine and Preparation Plant     Drummond Company Inc
# 18           Preparation Plant  Jesse Creek Mining, Llc
# ...

# %%
#15
df = pd.read_excel('employee.xlsx')
df[df['hire_date'] >='20070101']
# Out:
#     emp_id first_name   last_name  hire_date
# 4      104      Bruce       Ernst 2007-05-21
# 7      107      Diana     Lorentz 2007-02-07
# 13     113       Luis        Popp 2007-12-07
# 19     119      Karen  Colmenares 2007-08-10

# %%
#16
result = df.sort_values('hire_date')
result
# Out:
#     emp_id   first_name   last_name  hire_date
# 2      102          Lex     De Haan 2001-01-13
# 9      109       Daniel      Faviet 2002-08-16
# 8      108        Nancy   Greenberg 2002-08-17
# 14     114          Den    Raphaely 2002-12-07
# 15     115    Alexander        Khoo 2003-05-18
# 0      100       Steven        King 2003-06-17
# 5      105        David      Austin 2005-06-25
# 17     117        Sigal      Tobias 2005-07-24
# 1      101        Neena     Kochhar 2005-09-21
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 16     116       Shelli       Baida 2005-12-24
# 3      103    Alexander      Hunold 2006-01-03
# 6      106        Valli   Pataballa 2006-02-05
# 12     112  Jose Manuel       Urman 2006-03-07
# 18     118          Guy      Himuro 2006-11-15
# 7      107        Diana     Lorentz 2007-02-07
# 4      104        Bruce       Ernst 2007-05-21
# 19     119        Karen  Colmenares 2007-08-10
# ...

# %%
#17
result = df[(df['hire_date'] >='Jan-2005') & (df['hire_date'] <= 'Dec-2006')].head()
result
# Out:
#     emp_id first_name  last_name  hire_date
# 1      101      Neena    Kochhar 2005-09-21
# 3      103  Alexander     Hunold 2006-01-03
# 5      105      David     Austin 2005-06-25
# 6      106      Valli  Pataballa 2006-02-05
# 10     110       John       Chen 2005-09-28

# %%
#18
df2 = df.set_index(['hire_date'])
result = df2["2005"]
result
# Out:
#             emp_id first_name last_name
# hire_date
# 2005-09-21     101      Neena   Kochhar
# 2005-06-25     105      David    Austin
# 2005-09-28     110       John      Chen
# 2005-09-30     111     Ismael   Sciarra
# 2005-12-24     116     Shelli     Baida
# 2005-07-24     117      Sigal    Tobias

# %%
#19
result = df.set_index(['hire_date'])
result
# Out:
#             emp_id   first_name   last_name
# hire_date
# 2003-06-17     100       Steven        King
# 2005-09-21     101        Neena     Kochhar
# 2001-01-13     102          Lex     De Haan
# 2006-01-03     103    Alexander      Hunold
# 2007-05-21     104        Bruce       Ernst
# 2005-06-25     105        David      Austin
# 2006-02-05     106        Valli   Pataballa
# 2007-02-07     107        Diana     Lorentz
# 2002-08-17     108        Nancy   Greenberg
# 2002-08-16     109       Daniel      Faviet
# 2005-09-28     110         John        Chen
# 2005-09-30     111       Ismael     Sciarra
# 2006-03-07     112  Jose Manuel       Urman
# 2007-12-07     113         Luis        Popp
# 2002-12-07     114          Den    Raphaely
# 2003-05-18     115    Alexander        Khoo
# 2005-12-24     116       Shelli       Baida
# 2005-07-24     117        Sigal      Tobias
# 2006-11-15     118          Guy      Himuro
# 2007-08-10     119        Karen  Colmenares

# %%
#20
result = df.sort_values(by=['first_name','last_name'],ascending=[0,1])
result
# Out:
#     emp_id   first_name   last_name  hire_date
# 6      106        Valli   Pataballa 2006-02-05
# 0      100       Steven        King 2003-06-17
# 17     117        Sigal      Tobias 2005-07-24
# 16     116       Shelli       Baida 2005-12-24
# 1      101        Neena     Kochhar 2005-09-21
# 8      108        Nancy   Greenberg 2002-08-17
# 13     113         Luis        Popp 2007-12-07
# 2      102          Lex     De Haan 2001-01-13
# 19     119        Karen  Colmenares 2007-08-10
# 12     112  Jose Manuel       Urman 2006-03-07
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 18     118          Guy      Himuro 2006-11-15
# 7      107        Diana     Lorentz 2007-02-07
# 14     114          Den    Raphaely 2002-12-07
# 5      105        David      Austin 2005-06-25
# 9      109       Daniel      Faviet 2002-08-16
# 4      104        Bruce       Ernst 2007-05-21
# 3      103    Alexander      Hunold 2006-01-03
# ...

# %%
#21
df = pd.read_excel('employee.xlsx',sheet_name=1)
df.head()
# Out:
#    emp_id first_name last_name  hire_date
# 0     120    Matthew     Weiss 2004-07-18
# 1     121       Adam     Fripp 2005-04-10
# 2     122      Payam  Kaufling 2003-05-01
# 3     123     Shanta   Vollman 2005-10-10
# 4     124      Kevin   Mourgos 2007-11-16

# %%
#22
df1 = pd.read_excel('employee.xlsx',sheet_name=0)
df2 = pd.read_excel('employee.xlsx',sheet_name=1)
df3 = pd.read_excel('employee.xlsx',sheet_name=2)
df = pd.concat([df1, df2, df3])
df.head()
# Out:
#    emp_id first_name last_name  hire_date
# 0     100     Steven      King 2003-06-17
# 1     101      Neena   Kochhar 2005-09-21
# 2     102        Lex   De Haan 2001-01-13
# 3     103  Alexander    Hunold 2006-01-03
# 4     104      Bruce     Ernst 2007-05-21

# %%
#23
import matplotlib.pyplot as plt
df = pd.read_excel('coalpublic2013.xls',skiprows=3)
df.rename(columns={"Production (short tons)":"Production"},inplace=True)
sorted= df.sort_values(["Production"], ascending=False).head(10)
sorted["Production"].head(10).plot(kind="barh")
plt.show()

# %%
#24
df.head(10).plot(kind='bar', figsize=(20,8))
plt.show()

# %%
#25
df1 = pd.read_excel('employee.xlsx',sheet_name=0)
df2 = pd.read_excel('employee.xlsx',sheet_name=1)
df3 = pd.read_excel('employee.xlsx',sheet_name=2)
df = pd.concat([df1, df2, df3])
df.to_excel('new.xlsx', index=False)
